# %% [markdown]
# <a href="https://colab.research.google.com/github/subashshrestha1/Discrete_Math/blob/master/ProjectPart3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project Part # 3: CPSMA 3133 [Dr. Jacob's](https://github.com/nurfnick) Discrete Mathematics
#
# ## Structures and Numbers
#
# ### Subash Shrestha Submission

# %% [markdown]
# ## 1 Stuctures

# %% [markdown]
# I am going to present story about my educational journy through graph.
# I am going to connect all the School that I went through graph.
# Highschool I went to "Bishnu Devi", I went to two year college In "AIC" then I moved to United States at "UCO". after that I went to "OCCC and Went to "ECU", after completing at ECU, i am planning to go back to UCO for my Masters.

# %%
import graphviz
Subash = graphviz.Digraph('SubashCollegeHistory')
Subash.edge('Bishnu Devi', 'AIC', label = '2 year college')
Subash.edge('AIC','UCO','Started Undergrad')
Subash.edge('AIC','OCCC','Associate Degree')
Subash.edge('OCCC','UCO','One Semester')
Subash.edge('UCO','ECU','Transfered Undergrad')
Subash.edge('ECU','UCO','Going For Masters')

Subash

# %% [markdown]
# 1. Eular Path is not Possible
# 2. Hamilton Path is not possible.
#
# If we remove Ecu then eular and hamilton path is possible.

# %% [markdown]
# Degree of veteces are as follows
# Deg(Bishnu Devi)= 1
#
# Deg(AIC) = 2
#
# Deg(OCCC) = 2
#
# Deg(UCO) = 4
#
# Deg(ECU) = 2

# %% [markdown]
# Yes, there is cycle going from UCO to ECU.

# %% [markdown]
# Convert the number 240367 into base ten.

# %%
int('24036',7)
# Out:
# 6201

# %% [markdown]
# Convert the hexadecimal number 72e3 or 0x72e3 into base ten

# %%
int('0x72e3',16)
# Out:
# 29411

# %% [markdown]
# Convert 3735928559 into hexadecimal.
#
# It's funny the number cameout as DEADBEEF LOL...

# %%
hex(3735928559)
# Out:
# '0xdeadbeef'

# %% [markdown]
# Using two’s complement preform the base ten subtraction 25 − 37. Check your answer

# %%
bin(25)
# Out:
# '0b11001'

# %%
bin(37)
# Out:
# '0b100101'
